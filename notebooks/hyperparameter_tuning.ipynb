# %% [markdown]
# # Hyperparameter tuning

# %% [markdown]
# ## We selected top-3 models. Let's tune their hyperparameters

# %% [markdown]
# # Imports

# %%
# !pip install catboost -q
# !pip install xgboost==2.0.3 -q
# !pip install optuna -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 7.8 MB/s eta 0:00:00

# %%
import pandas as pd
import optuna
import catboost
import lightgbm as lgb
from catboost.utils import get_gpu_device_count
import xgboost as xgb
import cupy as cp
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import average_precision_score, balanced_accuracy_score
optuna.logging.set_verbosity(optuna.logging.INFO)

# %% [markdown]
# # Data

# %%
target = 'BANKR'

# %%
data = pd.read_csv('drive/MyDrive/data_catboost.csv')
X = data.drop(target, axis=1)
y = data[target]
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.15, stratify=y, random_state=42)

# %% [markdown]
# # Optuna

# %%
N_SPLITS = 3

# %% [markdown]
# ### Catboost

# %%
def set_to_gpu(params):
  has_gpu = get_gpu_device_count() > 0
  params["task_type"] = "GPU" if has_gpu else "CPU"
  params["devices"] = "0" if has_gpu else ""
  return params

# %%
def catboost_param_space(trial):
    params = {
        "iterations": trial.suggest_int("iterations", 800, 1800),
        "learning_rate": trial.suggest_float("learning_rate", 0.008, 0.03, log=True),
        "depth": trial.suggest_int("depth", 3, 6),
        "scale_pos_weight": trial.suggest_float("scale_pos_weight", 150, 350),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 3.0, 15.0),
        "border_count": trial.suggest_int("border_count", 32, 128),
        "random_strength": trial.suggest_float("random_strength", 0.0, 1.2),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 1.5),
        "eval_metric": "Logloss",
        "loss_function": "Logloss",
        "verbose": 250
    }
    params = set_to_gpu(params)

    return params

# %%
def cv_score_catboost(params, X, y, cv, metric='balanced_accuracy'):
    scores = []

    for train_idx, val_idx in cv.split(X, y):

        X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
        X_val, y_val = X.iloc[val_idx], y.iloc[val_idx]

        model = catboost.CatBoostClassifier(**params)
        model.fit(X_train, y_train, eval_set=[(X_val, y_val)],  verbose=False, early_stopping_rounds=100)

        if metric == "average_precision":
            y_val_proba = model.predict_proba(X_val)[:, 1]
            score = average_precision_score(y_val, y_val_proba)
        elif metric == "balanced_accuracy":
            y_val_pred = model.predict(X_val)
            score = balanced_accuracy_score(y_val, y_val_pred)
        else:
            raise ValueError("Unknown metric")
        scores.append(score)
    score = sum(scores) / len(scores)
    return score

# %%
def objective_catboost(trial):
    params = catboost_param_space(trial)
    kf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=42)
    score = cv_score_catboost(params=params,
                              X=X_train_full,
                              y=y_train_full,
                              cv=kf)
    return score

# %%
study_catboost = optuna.create_study(direction="maximize")
study_catboost.optimize(objective_catboost, n_trials=150)
# Out:
# [I 2025-11-30 13:58:54,710] A new study created in memory with name: no-name-5707417e-6fb4-4cd9-904d-ea46b767556a
# [I 2025-11-30 14:00:09,721] Trial 0 finished with value: 0.8468990108790863 and parameters: {'iterations': 1648, 'learning_rate': 0.009879256933546975, 'depth': 4, 'scale_pos_weight': 172.6822765298391, 'l2_leaf_reg': 3.5535746924138056, 'border_count': 120, 'random_strength': 0.4677096070499432, 'bagging_temperature': 0.5962009640151342}. Best is trial 0 with value: 0.8468990108790863.
# [I 2025-11-30 14:00:49,223] Trial 1 finished with value: 0.8543149006778995 and parameters: {'iterations': 1397, 'learning_rate': 0.02460559773182291, 'depth': 3, 'scale_pos_weight': 295.21864117153905, 'l2_leaf_reg': 10.45649631998873, 'border_count': 90, 'random_strength': 0.2892756311588285, 'bagging_temperature': 0.03670846288908697}. Best is trial 1 with value: 0.8543149006778995.
# [I 2025-11-30 14:01:34,815] Trial 2 finished with value: 0.8505047963920987 and parameters: {'iterations': 914, 'learning_rate': 0.010220319535135493, 'depth': 3, 'scale_pos_weight': 285.11446151329983, 'l2_leaf_reg': 11.947407754695114, 'border_count': 110, 'random_strength': 1.0030889705012704, 'bagging_temperature': 0.9471914227386866}. Best is trial 1 with value: 0.8543149006778995.
# [I 2025-11-30 14:02:09,550] Trial 3 finished with value: 0.8521289045610666 and parameters: {'iterations': 1393, 'learning_rate': 0.02701383761223009, 'depth': 5, 'scale_pos_weight': 349.38173986776644, 'l2_leaf_reg': 12.490232188382207, 'border_count': 68, 'random_strength': 0.2854440747163919, 'bagging_temperature': 0.7144690267049181}. Best is trial 1 with value: 0.8543149006778995.
# [I 2025-11-30 14:03:10,639] Trial 4 finished with value: 0.8521818836629557 and parameters: {'iterations': 1379, 'learning_rate': 0.008049002230945982, 'depth': 3, 'scale_pos_weight': 310.70301991448093, 'l2_leaf_reg': 10.796058362109454, 'border_count': 123, 'random_strength': 0.29087246105711745, 'bagging_temperature': 0.5580983995897059}. Best is trial 1 with value: 0.8543149006778995.
# [I 2025-11-30 14:04:14,769] Trial 5 finished with value: 0.8467771607825108 and parameters: {'iterations': 966, 'learning_rate': 0.008158116374097761, 'depth': 6, 'scale_pos_weight': 182.1335391517836, 'l2_leaf_reg': 7.870783859787197, 'border_count': 95, 'random_strength': 1.1745525977881084, 'bagging_temperature': 0.8434419604125851}. Best is trial 1 with value: 0.8543149006778995.
# [I 2025-11-30 14:04:54,006] Trial 6 finished with value: 0.8534287446351662 and parameters: {'iterations': 1445, 'learning_rate': 0.029538806072623477, 'depth': 4, 'scale_pos_weight': 325.18269098030925, 'l2_leaf_reg': 9.533129135712644, 'border_count': 122, 'random_strength': 0.6456288799618389, 'bagging_temperature': 0.2231268185112978}. Best is trial 1 with value: 0.8543149006778995.
# [I 2025-11-30 14:05:36,148] Trial 7 finished with value: 0.8480157534067502 and parameters: {'iterations': 1340, 'learning_rate': 0.014581812259790376, 'depth': 6, 'scale_pos_weight': 229.2155737105976, 'l2_leaf_reg': 3.3487182191527154, 'border_count': 127, 'random_strength': 0.7166285860688566, 'bagging_temperature': 0.9081604249511452}. Best is trial 1 with value: 0.8543149006778995.
# [I 2025-11-30 14:06:24,793] Trial 8 finished with value: 0.855555644414954 and parameters: {'iterations': 1692, 'learning_rate': 0.017026374776078913, 'depth': 4, 'scale_pos_weight': 316.58468555611665, 'l2_leaf_reg': 3.094327798096263, 'border_count': 110, 'random_strength': 0.305189837832784, 'bagging_temperature': 1.0327214455007152}. Best is trial 8 with value: 0.855555644414954.
# [I 2025-11-30 14:07:00,396] Trial 9 finished with value: 0.841322424234669 and parameters: {'iterations': 1556, 'learning_rate': 0.02463996369723097, 'depth': 6, 'scale_pos_weight': 159.85472981377694, 'l2_leaf_reg': 8.950561564507403, 'border_count': 69, 'random_strength': 0.3456553081100768, 'bagging_temperature': 0.8517418967121841}. Best is trial 8 with value: 0.855555644414954.
# [I 2025-11-30 14:07:42,927] Trial 10 finished with value: 0.8546443534595456 and parameters: {'iterations': 1791, 'learning_rate': 0.01899407230774969, 'depth': 5, 'scale_pos_weight': 254.1104907182531, 'l2_leaf_reg': 14.955145237176641, 'border_count': 35, 'random_strength': 0.007074266856880174, 'bagging_temperature': 1.4917416430102883}. Best is trial 8 with value: 0.855555644414954.
# [I 2025-11-30 14:08:23,607] Trial 11 finished with value: 0.8535134092607285 and parameters: {'iterations': 1752, 'learning_rate': 0.01783675059623157, 'depth': 5, 'scale_pos_weight': 246.37898023366728, 'l2_leaf_reg': 14.44252578983457, 'border_count': 32, 'random_strength': 0.021500114299281742, 'bagging_temperature': 1.462213074484182}. Best is trial 8 with value: 0.855555644414954.
# [I 2025-11-30 14:09:08,319] Trial 12 finished with value: 0.8569478251954498 and parameters: {'iterations': 1797, 'learning_rate': 0.018025492256144894, 'depth': 4, 'scale_pos_weight': 270.38631026291466, 'l2_leaf_reg': 6.493820733442361, 'border_count': 32, 'random_strength': 0.018697750078003082, 'bagging_temperature': 1.4683726573539158}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:10:02,497] Trial 13 finished with value: 0.8544976460028954 and parameters: {'iterations': 1128, 'learning_rate': 0.014882724373347447, 'depth': 4, 'scale_pos_weight': 271.5848760849472, 'l2_leaf_reg': 5.9167897982392645, 'border_count': 51, 'random_strength': 0.11334438182969284, 'bagging_temperature': 1.1898456190710966}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:10:59,815] Trial 14 finished with value: 0.8527835114151657 and parameters: {'iterations': 1607, 'learning_rate': 0.018411876353832488, 'depth': 4, 'scale_pos_weight': 207.9250722152079, 'l2_leaf_reg': 5.656435018584626, 'border_count': 100, 'random_strength': 0.1702993418728595, 'bagging_temperature': 1.2786893700796322}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:11:54,132] Trial 15 finished with value: 0.8535782478119925 and parameters: {'iterations': 1187, 'learning_rate': 0.013272732244238016, 'depth': 4, 'scale_pos_weight': 347.1732424518012, 'l2_leaf_reg': 5.678809502852542, 'border_count': 78, 'random_strength': 0.4670857402840487, 'bagging_temperature': 1.164493944873496}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:12:28,903] Trial 16 finished with value: 0.8535655111583315 and parameters: {'iterations': 1675, 'learning_rate': 0.02107055050240945, 'depth': 5, 'scale_pos_weight': 315.4993391862651, 'l2_leaf_reg': 7.146446753673384, 'border_count': 47, 'random_strength': 0.8004907027105194, 'bagging_temperature': 1.0674574012869142}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:13:35,381] Trial 17 finished with value: 0.8528719527750571 and parameters: {'iterations': 1528, 'learning_rate': 0.01226857512605203, 'depth': 3, 'scale_pos_weight': 267.8821324795498, 'l2_leaf_reg': 4.324615322312585, 'border_count': 108, 'random_strength': 0.5110440731377328, 'bagging_temperature': 1.3352791593914222}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:14:21,963] Trial 18 finished with value: 0.8495594671041896 and parameters: {'iterations': 1726, 'learning_rate': 0.016641314339989197, 'depth': 4, 'scale_pos_weight': 225.1398184223869, 'l2_leaf_reg': 4.983772940355941, 'border_count': 55, 'random_strength': 0.16416473662827374, 'bagging_temperature': 0.41946033449580983}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:15:01,983] Trial 19 finished with value: 0.8519625451587642 and parameters: {'iterations': 1184, 'learning_rate': 0.020941784729910706, 'depth': 5, 'scale_pos_weight': 295.8745417353462, 'l2_leaf_reg': 7.134601003491051, 'border_count': 84, 'random_strength': 0.1281552741283467, 'bagging_temperature': 1.017066943483735}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:15:42,350] Trial 20 finished with value: 0.8527923240062947 and parameters: {'iterations': 806, 'learning_rate': 0.021441472698041752, 'depth': 3, 'scale_pos_weight': 327.48629940863566, 'l2_leaf_reg': 3.2383884023270753, 'border_count': 62, 'random_strength': 0.36243438286064555, 'bagging_temperature': 1.3378676285563362}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:16:24,272] Trial 21 finished with value: 0.854340059592741 and parameters: {'iterations': 1733, 'learning_rate': 0.018734339024811357, 'depth': 5, 'scale_pos_weight': 253.75241113942184, 'l2_leaf_reg': 14.836628922568375, 'border_count': 36, 'random_strength': 0.014623097253566818, 'bagging_temperature': 1.4940118831214313}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:17:22,182] Trial 22 finished with value: 0.8562067453941892 and parameters: {'iterations': 1798, 'learning_rate': 0.016147078596103776, 'depth': 4, 'scale_pos_weight': 259.32498200718027, 'l2_leaf_reg': 13.54872489952508, 'border_count': 41, 'random_strength': 0.04327288713551118, 'bagging_temperature': 1.4223179388697889}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:18:15,088] Trial 23 finished with value: 0.8536611145159109 and parameters: {'iterations': 1525, 'learning_rate': 0.01600508170136117, 'depth': 4, 'scale_pos_weight': 269.7193879224217, 'l2_leaf_reg': 13.22597421606884, 'border_count': 46, 'random_strength': 0.20653757907198564, 'bagging_temperature': 1.1533210858930947}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:19:20,359] Trial 24 finished with value: 0.8528900809756678 and parameters: {'iterations': 1800, 'learning_rate': 0.013277618508937264, 'depth': 4, 'scale_pos_weight': 231.72453131002203, 'l2_leaf_reg': 8.297288773368754, 'border_count': 41, 'random_strength': 0.08784356223517464, 'bagging_temperature': 1.3330340079530814}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:20:25,569] Trial 25 finished with value: 0.8520478560223829 and parameters: {'iterations': 1641, 'learning_rate': 0.011705149868804941, 'depth': 4, 'scale_pos_weight': 199.01722187339377, 'l2_leaf_reg': 6.8918933145874774, 'border_count': 57, 'random_strength': 0.21149570653739344, 'bagging_temperature': 1.2388013420770054}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:21:19,724] Trial 26 finished with value: 0.8560234979107847 and parameters: {'iterations': 1698, 'learning_rate': 0.016608635438377154, 'depth': 4, 'scale_pos_weight': 294.59968146824093, 'l2_leaf_reg': 4.4788591485365465, 'border_count': 76, 'random_strength': 0.06666121055577527, 'bagging_temperature': 1.4001633357413985}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:22:16,526] Trial 27 finished with value: 0.8534324143112467 and parameters: {'iterations': 1575, 'learning_rate': 0.01350904337730831, 'depth': 3, 'scale_pos_weight': 284.8827285177702, 'l2_leaf_reg': 4.645916322562246, 'border_count': 42, 'random_strength': 0.8917451309609483, 'bagging_temperature': 1.3989204417889924}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:23:21,028] Trial 28 finished with value: 0.8537107842417972 and parameters: {'iterations': 1475, 'learning_rate': 0.014670198743992075, 'depth': 4, 'scale_pos_weight': 246.77881291318602, 'l2_leaf_reg': 6.493579175673145, 'border_count': 79, 'random_strength': 0.0788711012140988, 'bagging_temperature': 1.387653733677141}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:24:07,819] Trial 29 finished with value: 0.8556688842688533 and parameters: {'iterations': 1644, 'learning_rate': 0.02020143008655586, 'depth': 4, 'scale_pos_weight': 297.67839783015626, 'l2_leaf_reg': 3.9902187639529108, 'border_count': 71, 'random_strength': 0.48836679801413185, 'bagging_temperature': 1.112223253262457}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:24:53,892] Trial 30 finished with value: 0.8549610301104251 and parameters: {'iterations': 1278, 'learning_rate': 0.010533518833661625, 'depth': 5, 'scale_pos_weight': 277.61509549417883, 'l2_leaf_reg': 13.50273754221962, 'border_count': 40, 'random_strength': 0.398521041258433, 'bagging_temperature': 0.6753817934870099}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:25:45,851] Trial 31 finished with value: 0.8552554175771246 and parameters: {'iterations': 1658, 'learning_rate': 0.019961064009225125, 'depth': 4, 'scale_pos_weight': 297.93860545780495, 'l2_leaf_reg': 4.627730950659323, 'border_count': 71, 'random_strength': 0.5704921146473573, 'bagging_temperature': 1.2538566558681108}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:26:25,451] Trial 32 finished with value: 0.8561542494458326 and parameters: {'iterations': 1749, 'learning_rate': 0.02352826187229222, 'depth': 4, 'scale_pos_weight': 303.51737859372395, 'l2_leaf_reg': 3.9919291568438804, 'border_count': 61, 'random_strength': 0.07345979901630835, 'bagging_temperature': 1.4213502815135939}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:27:24,432] Trial 33 finished with value: 0.8560111453747764 and parameters: {'iterations': 1799, 'learning_rate': 0.015864467886139474, 'depth': 3, 'scale_pos_weight': 306.09873251015534, 'l2_leaf_reg': 5.217916427955025, 'border_count': 63, 'random_strength': 0.2217346908136238, 'bagging_temperature': 1.4247373209368601}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:28:03,005] Trial 34 finished with value: 0.8544050530274437 and parameters: {'iterations': 1726, 'learning_rate': 0.023048522951260825, 'depth': 4, 'scale_pos_weight': 287.7570036539643, 'l2_leaf_reg': 6.298115316557492, 'border_count': 50, 'random_strength': 0.07014334119752687, 'bagging_temperature': 1.2867774746167737}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:28:57,469] Trial 35 finished with value: 0.8550461465819486 and parameters: {'iterations': 1718, 'learning_rate': 0.02306307923463131, 'depth': 3, 'scale_pos_weight': 261.6351081580204, 'l2_leaf_reg': 10.325455881297708, 'border_count': 59, 'random_strength': 0.24463046336122207, 'bagging_temperature': 1.3965298796680514}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:29:40,394] Trial 36 finished with value: 0.854918211886074 and parameters: {'iterations': 1596, 'learning_rate': 0.02620276678045685, 'depth': 4, 'scale_pos_weight': 334.1616147837491, 'l2_leaf_reg': 11.551235141733752, 'border_count': 86, 'random_strength': 0.0018506681253126905, 'bagging_temperature': 1.4945769122619543}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:30:16,216] Trial 37 finished with value: 0.8547429247141937 and parameters: {'iterations': 1763, 'learning_rate': 0.017760793474538284, 'depth': 4, 'scale_pos_weight': 280.3463752456795, 'l2_leaf_reg': 3.856319149470659, 'border_count': 32, 'random_strength': 0.1357453609525806, 'bagging_temperature': 0.11357833365674264}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:31:11,130] Trial 38 finished with value: 0.852475737213318 and parameters: {'iterations': 1683, 'learning_rate': 0.022595195820006422, 'depth': 3, 'scale_pos_weight': 242.8893852492191, 'l2_leaf_reg': 7.839354892429327, 'border_count': 76, 'random_strength': 1.1121164610796557, 'bagging_temperature': 0.519626106578136}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:31:48,733] Trial 39 finished with value: 0.8531753421095741 and parameters: {'iterations': 1469, 'learning_rate': 0.02770161992944069, 'depth': 5, 'scale_pos_weight': 305.1221557968525, 'l2_leaf_reg': 5.216540561162744, 'border_count': 92, 'random_strength': 0.061798241831819915, 'bagging_temperature': 1.2149635089660145}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:32:33,658] Trial 40 finished with value: 0.8539794160910158 and parameters: {'iterations': 978, 'learning_rate': 0.016781139997067082, 'depth': 4, 'scale_pos_weight': 261.68216782545437, 'l2_leaf_reg': 11.442066179801385, 'border_count': 64, 'random_strength': 0.26888675868953654, 'bagging_temperature': 0.945431587653216}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:33:32,033] Trial 41 finished with value: 0.855898567032224 and parameters: {'iterations': 1797, 'learning_rate': 0.01592084430491086, 'depth': 3, 'scale_pos_weight': 307.0228899141606, 'l2_leaf_reg': 5.127141955109067, 'border_count': 53, 'random_strength': 0.12349239844316823, 'bagging_temperature': 1.4112615216773874}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:34:34,688] Trial 42 finished with value: 0.8545466508929143 and parameters: {'iterations': 1744, 'learning_rate': 0.01507411025215826, 'depth': 3, 'scale_pos_weight': 288.61989301103904, 'l2_leaf_reg': 3.900278252756599, 'border_count': 64, 'random_strength': 0.19218593274954882, 'bagging_temperature': 1.3901441154276428}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:35:46,361] Trial 43 finished with value: 0.8550799475978274 and parameters: {'iterations': 1792, 'learning_rate': 0.014065397883794722, 'depth': 3, 'scale_pos_weight': 317.3548807775742, 'l2_leaf_reg': 9.666119606475956, 'border_count': 73, 'random_strength': 0.04868392662711729, 'bagging_temperature': 1.4368499484625055}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:36:43,714] Trial 44 finished with value: 0.8551131423124284 and parameters: {'iterations': 1695, 'learning_rate': 0.015852757030786913, 'depth': 4, 'scale_pos_weight': 339.2668967315978, 'l2_leaf_reg': 5.485652796303567, 'border_count': 66, 'random_strength': 0.24402335592677743, 'bagging_temperature': 1.3027607957504268}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:37:41,526] Trial 45 finished with value: 0.8515059601425046 and parameters: {'iterations': 1622, 'learning_rate': 0.008803509951720415, 'depth': 3, 'scale_pos_weight': 292.43943942165055, 'l2_leaf_reg': 4.373026119020622, 'border_count': 45, 'random_strength': 0.32514577809957673, 'bagging_temperature': 1.3527111542072787}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:38:14,234] Trial 46 finished with value: 0.8513905488789059 and parameters: {'iterations': 1760, 'learning_rate': 0.01760766564863128, 'depth': 6, 'scale_pos_weight': 323.45924673653485, 'l2_leaf_reg': 6.246958071514512, 'border_count': 59, 'random_strength': 0.1532257608833133, 'bagging_temperature': 0.32054624100223084}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:39:00,638] Trial 47 finished with value: 0.855661138958653 and parameters: {'iterations': 1693, 'learning_rate': 0.019537349713719544, 'depth': 4, 'scale_pos_weight': 307.1242140204557, 'l2_leaf_reg': 3.0894254865054953, 'border_count': 37, 'random_strength': 0.40053190646113107, 'bagging_temperature': 1.4397094280374954}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:39:50,916] Trial 48 finished with value: 0.8531436081667918 and parameters: {'iterations': 1765, 'learning_rate': 0.01175842012064658, 'depth': 5, 'scale_pos_weight': 277.3523626930092, 'l2_leaf_reg': 7.944645927022416, 'border_count': 82, 'random_strength': 0.057124689040370234, 'bagging_temperature': 0.7627727346737015}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:40:47,381] Trial 49 finished with value: 0.8525514002735693 and parameters: {'iterations': 1541, 'learning_rate': 0.012544971569155352, 'depth': 4, 'scale_pos_weight': 238.2642633618367, 'l2_leaf_reg': 3.707652929605072, 'border_count': 48, 'random_strength': 0.6863511896493841, 'bagging_temperature': 1.089313410840217}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:41:41,493] Trial 50 finished with value: 0.8536920403280658 and parameters: {'iterations': 1652, 'learning_rate': 0.029552676017260394, 'depth': 3, 'scale_pos_weight': 215.27273755361594, 'l2_leaf_reg': 8.869798825129596, 'border_count': 98, 'random_strength': 0.0017125935971698675, 'bagging_temperature': 1.1976229495728248}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:42:42,414] Trial 51 finished with value: 0.8551560871851821 and parameters: {'iterations': 1783, 'learning_rate': 0.015782651279368787, 'depth': 3, 'scale_pos_weight': 304.8790192681165, 'l2_leaf_reg': 5.024688640212598, 'border_count': 52, 'random_strength': 0.10977521926893626, 'bagging_temperature': 1.4374295483032133}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:43:42,957] Trial 52 finished with value: 0.8554149967616097 and parameters: {'iterations': 1795, 'learning_rate': 0.0163173518764496, 'depth': 3, 'scale_pos_weight': 313.8135435395569, 'l2_leaf_reg': 5.844436400567027, 'border_count': 54, 'random_strength': 0.12168834297759504, 'bagging_temperature': 1.4283126606022476}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:44:44,580] Trial 53 finished with value: 0.8549776282568168 and parameters: {'iterations': 1713, 'learning_rate': 0.01724852971781019, 'depth': 3, 'scale_pos_weight': 259.8063196760584, 'l2_leaf_reg': 4.942100268722296, 'border_count': 38, 'random_strength': 0.1794884555906508, 'bagging_temperature': 1.4971208567188328}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:45:43,551] Trial 54 finished with value: 0.853871533900024 and parameters: {'iterations': 1745, 'learning_rate': 0.014092494943109189, 'depth': 3, 'scale_pos_weight': 302.8070319876009, 'l2_leaf_reg': 6.715761514855689, 'border_count': 43, 'random_strength': 0.04327654618387412, 'bagging_temperature': 1.3415638863534076}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:46:27,523] Trial 55 finished with value: 0.8551191223227136 and parameters: {'iterations': 1799, 'learning_rate': 0.018530817747516318, 'depth': 4, 'scale_pos_weight': 324.66071857478914, 'l2_leaf_reg': 7.467509016262975, 'border_count': 61, 'random_strength': 0.10812000899707055, 'bagging_temperature': 1.2731941985941027}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:47:18,884] Trial 56 finished with value: 0.8554845153867937 and parameters: {'iterations': 1686, 'learning_rate': 0.01501533192669217, 'depth': 4, 'scale_pos_weight': 281.88246912121434, 'l2_leaf_reg': 4.206295115751338, 'border_count': 55, 'random_strength': 0.22876329112979005, 'bagging_temperature': 1.3623064212293245}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:48:15,566] Trial 57 finished with value: 0.8531311513207163 and parameters: {'iterations': 1599, 'learning_rate': 0.01394231421227888, 'depth': 4, 'scale_pos_weight': 269.98869972029104, 'l2_leaf_reg': 3.4832419816474305, 'border_count': 67, 'random_strength': 0.28120217348355886, 'bagging_temperature': 1.0003957911585912}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:48:54,875] Trial 58 finished with value: 0.8557162647796966 and parameters: {'iterations': 1067, 'learning_rate': 0.024690416666755314, 'depth': 3, 'scale_pos_weight': 311.854159897174, 'l2_leaf_reg': 5.361771187628208, 'border_count': 50, 'random_strength': 0.16257580449453057, 'bagging_temperature': 1.1615991789978906}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:49:37,276] Trial 59 finished with value: 0.8550416009664641 and parameters: {'iterations': 1751, 'learning_rate': 0.016887803880471328, 'depth': 4, 'scale_pos_weight': 334.7978766262744, 'l2_leaf_reg': 6.025250339240914, 'border_count': 32, 'random_strength': 0.09513281901582393, 'bagging_temperature': 1.2999953292955364}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:50:25,934] Trial 60 finished with value: 0.8518925353737501 and parameters: {'iterations': 1315, 'learning_rate': 0.015459438932308583, 'depth': 5, 'scale_pos_weight': 274.3217915661244, 'l2_leaf_reg': 4.631777002539518, 'border_count': 75, 'random_strength': 0.03690036870773876, 'bagging_temperature': 1.445147778789021}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:51:08,151] Trial 61 finished with value: 0.8554436045762972 and parameters: {'iterations': 988, 'learning_rate': 0.025097779986518985, 'depth': 3, 'scale_pos_weight': 309.76258458421796, 'l2_leaf_reg': 5.343033873568054, 'border_count': 49, 'random_strength': 0.15422841460071457, 'bagging_temperature': 1.1406541982429583}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:51:52,818] Trial 62 finished with value: 0.855995400497337 and parameters: {'iterations': 1222, 'learning_rate': 0.02646230543125809, 'depth': 3, 'scale_pos_weight': 292.998323240949, 'l2_leaf_reg': 5.4139207741194415, 'border_count': 44, 'random_strength': 0.1876306209305915, 'bagging_temperature': 1.2276410076754443}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:52:42,215] Trial 63 finished with value: 0.8568777245969583 and parameters: {'iterations': 1256, 'learning_rate': 0.02668781571724646, 'depth': 3, 'scale_pos_weight': 292.90502088843573, 'l2_leaf_reg': 12.531360736906368, 'border_count': 43, 'random_strength': 0.19686871697417402, 'bagging_temperature': 1.3862863469444928}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:53:28,952] Trial 64 finished with value: 0.8451972901557081 and parameters: {'iterations': 1246, 'learning_rate': 0.027824542948756536, 'depth': 3, 'scale_pos_weight': 153.78047313787616, 'l2_leaf_reg': 12.811366211855928, 'border_count': 39, 'random_strength': 0.20878172376963722, 'bagging_temperature': 1.2389784865329176}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:54:03,215] Trial 65 finished with value: 0.8560207648679939 and parameters: {'iterations': 1220, 'learning_rate': 0.02659290691711215, 'depth': 4, 'scale_pos_weight': 292.9777262572316, 'l2_leaf_reg': 13.589124310695567, 'border_count': 44, 'random_strength': 0.3120517951158055, 'bagging_temperature': 1.3219843767004824}. Best is trial 12 with value: 0.8569478251954498.
# [I 2025-11-30 14:54:51,166] Trial 66 finished with value: 0.8577185208453052 and parameters: {'iterations': 1371, 'learning_rate': 0.021814640804708095, 'depth': 4, 'scale_pos_weight': 300.0491028178344, 'l2_leaf_reg': 13.529111557732534, 'border_count': 34, 'random_strength': 0.3762614603148301, 'bagging_temperature': 1.4746642632562}. Best is trial 66 with value: 0.8577185208453052.
# [I 2025-11-30 14:55:34,343] Trial 67 finished with value: 0.8578257688678043 and parameters: {'iterations': 1341, 'learning_rate': 0.021895456543480893, 'depth': 4, 'scale_pos_weight': 298.86511294015463, 'l2_leaf_reg': 13.859865526216618, 'border_count': 36, 'random_strength': 0.4381727087462759, 'bagging_temperature': 1.497181431192364}. Best is trial 67 with value: 0.8578257688678043.
# [I 2025-11-30 14:56:16,908] Trial 68 finished with value: 0.8566603912444147 and parameters: {'iterations': 1364, 'learning_rate': 0.02153382837188439, 'depth': 4, 'scale_pos_weight': 299.0416982070507, 'l2_leaf_reg': 14.131740578794505, 'border_count': 35, 'random_strength': 0.44979782110386135, 'bagging_temperature': 1.4881429556975212}. Best is trial 67 with value: 0.8578257688678043.
# [I 2025-11-30 14:56:59,891] Trial 69 finished with value: 0.8580859903374266 and parameters: {'iterations': 1349, 'learning_rate': 0.02217613327686828, 'depth': 4, 'scale_pos_weight': 299.8105782885799, 'l2_leaf_reg': 14.192356632308242, 'border_count': 35, 'random_strength': 0.4372791038481647, 'bagging_temperature': 1.4997928852113191}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 14:57:52,828] Trial 70 finished with value: 0.850218388229652 and parameters: {'iterations': 1364, 'learning_rate': 0.021828277147182523, 'depth': 4, 'scale_pos_weight': 179.13924205704845, 'l2_leaf_reg': 14.111160094032657, 'border_count': 35, 'random_strength': 0.565508638124835, 'bagging_temperature': 1.4753254210097901}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 14:58:33,692] Trial 71 finished with value: 0.8567312223854309 and parameters: {'iterations': 1404, 'learning_rate': 0.023785240431441066, 'depth': 4, 'scale_pos_weight': 298.8590769771675, 'l2_leaf_reg': 14.27715955729485, 'border_count': 34, 'random_strength': 0.45139021797927836, 'bagging_temperature': 1.474772753807224}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 14:59:17,018] Trial 72 finished with value: 0.856963783369921 and parameters: {'iterations': 1415, 'learning_rate': 0.020648934481287205, 'depth': 4, 'scale_pos_weight': 284.8472804853088, 'l2_leaf_reg': 14.242626300330784, 'border_count': 34, 'random_strength': 0.4475083913963089, 'bagging_temperature': 1.476033322960765}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:00:09,478] Trial 73 finished with value: 0.857430154793717 and parameters: {'iterations': 1427, 'learning_rate': 0.020734399299935632, 'depth': 4, 'scale_pos_weight': 286.54831427087254, 'l2_leaf_reg': 14.279039361283106, 'border_count': 35, 'random_strength': 0.4379643770756934, 'bagging_temperature': 1.4951734963313008}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:00:50,898] Trial 74 finished with value: 0.8566000390432534 and parameters: {'iterations': 1428, 'learning_rate': 0.020355340803200856, 'depth': 4, 'scale_pos_weight': 284.7100490666582, 'l2_leaf_reg': 14.620519518296758, 'border_count': 32, 'random_strength': 0.42702639912905294, 'bagging_temperature': 1.3832044452522496}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:01:31,128] Trial 75 finished with value: 0.8559274272730951 and parameters: {'iterations': 1323, 'learning_rate': 0.02367022729222401, 'depth': 4, 'scale_pos_weight': 266.29741641941223, 'l2_leaf_reg': 12.537009994528779, 'border_count': 35, 'random_strength': 0.5027944106039953, 'bagging_temperature': 1.4635920172702828}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:02:12,722] Trial 76 finished with value: 0.8562885121935278 and parameters: {'iterations': 1409, 'learning_rate': 0.022172492196673766, 'depth': 4, 'scale_pos_weight': 288.31055893229575, 'l2_leaf_reg': 13.992034656790059, 'border_count': 40, 'random_strength': 0.37594304422150143, 'bagging_temperature': 1.4955265061785745}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:02:47,405] Trial 77 finished with value: 0.8555774101811348 and parameters: {'iterations': 1278, 'learning_rate': 0.020738870775776415, 'depth': 5, 'scale_pos_weight': 318.68096549994186, 'l2_leaf_reg': 13.14535880748975, 'border_count': 37, 'random_strength': 0.6285212440882195, 'bagging_temperature': 1.360463727612931}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:03:30,455] Trial 78 finished with value: 0.8571150207768808 and parameters: {'iterations': 1505, 'learning_rate': 0.025461311993015632, 'depth': 4, 'scale_pos_weight': 275.01599325024245, 'l2_leaf_reg': 14.893001891917796, 'border_count': 34, 'random_strength': 0.5551731246702987, 'bagging_temperature': 1.4574565898981042}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:04:12,485] Trial 79 finished with value: 0.8549467155656129 and parameters: {'iterations': 1462, 'learning_rate': 0.025542238667682144, 'depth': 4, 'scale_pos_weight': 254.72184198748434, 'l2_leaf_reg': 13.844406277600172, 'border_count': 41, 'random_strength': 0.5574010246707148, 'bagging_temperature': 1.370334882287837}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:05:05,571] Trial 80 finished with value: 0.8563438154251903 and parameters: {'iterations': 1486, 'learning_rate': 0.019086586973683522, 'depth': 4, 'scale_pos_weight': 275.86635911836174, 'l2_leaf_reg': 14.757274641163892, 'border_count': 38, 'random_strength': 0.5250035422041522, 'bagging_temperature': 1.4589117710025195}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:05:46,662] Trial 81 finished with value: 0.8570697631610465 and parameters: {'iterations': 1391, 'learning_rate': 0.02393834025121292, 'depth': 4, 'scale_pos_weight': 299.47090841826986, 'l2_leaf_reg': 14.418558816328499, 'border_count': 34, 'random_strength': 0.46231209906112897, 'bagging_temperature': 1.458254855202586}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:06:23,726] Trial 82 finished with value: 0.857518802697446 and parameters: {'iterations': 1342, 'learning_rate': 0.02811923107722542, 'depth': 4, 'scale_pos_weight': 285.34396728439816, 'l2_leaf_reg': 14.976088862771004, 'border_count': 32, 'random_strength': 0.34064346843400467, 'bagging_temperature': 1.3998752949649136}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:07:03,173] Trial 83 finished with value: 0.8549757470967411 and parameters: {'iterations': 1505, 'learning_rate': 0.0278996717831025, 'depth': 4, 'scale_pos_weight': 281.37458650656106, 'l2_leaf_reg': 14.577301252478286, 'border_count': 32, 'random_strength': 0.34953061549052594, 'bagging_temperature': 1.3186218848182307}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:07:49,186] Trial 84 finished with value: 0.8563505023895669 and parameters: {'iterations': 1369, 'learning_rate': 0.02221236623642447, 'depth': 4, 'scale_pos_weight': 265.4618002641045, 'l2_leaf_reg': 14.847368734296133, 'border_count': 35, 'random_strength': 0.42026696715972955, 'bagging_temperature': 1.4568189317246871}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:08:38,870] Trial 85 finished with value: 0.8568810268505246 and parameters: {'iterations': 1342, 'learning_rate': 0.019631730983285498, 'depth': 4, 'scale_pos_weight': 285.5293027355747, 'l2_leaf_reg': 14.952724431896858, 'border_count': 39, 'random_strength': 0.4806149617878803, 'bagging_temperature': 1.3957328505932625}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:09:16,480] Trial 86 finished with value: 0.8571930924807151 and parameters: {'iterations': 1443, 'learning_rate': 0.02874495530004347, 'depth': 4, 'scale_pos_weight': 301.3181258064953, 'l2_leaf_reg': 14.43167874300917, 'border_count': 33, 'random_strength': 0.530297889207575, 'bagging_temperature': 1.4222287804219669}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:10:01,588] Trial 87 finished with value: 0.856203425683867 and parameters: {'iterations': 1442, 'learning_rate': 0.028669274536805133, 'depth': 4, 'scale_pos_weight': 300.6329779486769, 'l2_leaf_reg': 13.719571825174, 'border_count': 114, 'random_strength': 0.626111684803355, 'bagging_temperature': 1.4999538994875667}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:10:42,481] Trial 88 finished with value: 0.8561775447056039 and parameters: {'iterations': 1421, 'learning_rate': 0.025779467181883474, 'depth': 4, 'scale_pos_weight': 320.21949314089125, 'l2_leaf_reg': 13.30501072528634, 'border_count': 46, 'random_strength': 0.5327688879031947, 'bagging_temperature': 1.4132356231436096}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:11:22,311] Trial 89 finished with value: 0.856137148320737 and parameters: {'iterations': 1341, 'learning_rate': 0.024265726101584187, 'depth': 4, 'scale_pos_weight': 291.2123546781437, 'l2_leaf_reg': 14.410938692817906, 'border_count': 37, 'random_strength': 0.37695622804695944, 'bagging_temperature': 1.3489334598746148}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:12:00,491] Trial 90 finished with value: 0.8571799509758806 and parameters: {'iterations': 1391, 'learning_rate': 0.028952720459618386, 'depth': 4, 'scale_pos_weight': 297.21555936275746, 'l2_leaf_reg': 12.802576378337974, 'border_count': 34, 'random_strength': 0.47151903757008534, 'bagging_temperature': 1.2794676143173278}. Best is trial 69 with value: 0.8580859903374266.
# [I 2025-11-30 15:12:42,418] Trial 91 finished with value: 0.8586225119867786 and parameters: {'iterations': 1390, 'learning_rate': 0.028573609421054653, 'depth': 4, 'scale_pos_weight': 312.05844390849785, 'l2_leaf_reg': 12.999957278907168, 'border_count': 34, 'random_strength': 0.5936070597315556, 'bagging_temperature': 1.4471876815715616}. Best is trial 91 with value: 0.8586225119867786.
# [I 2025-11-30 15:13:21,023] Trial 92 finished with value: 0.856464637334998 and parameters: {'iterations': 1293, 'learning_rate': 0.029584183096645483, 'depth': 4, 'scale_pos_weight': 309.4904779112401, 'l2_leaf_reg': 12.099265125727776, 'border_count': 41, 'random_strength': 0.6760449005577791, 'bagging_temperature': 1.4308113862921303}. Best is trial 91 with value: 0.8586225119867786.
# [I 2025-11-30 15:13:58,670] Trial 93 finished with value: 0.8563022339764901 and parameters: {'iterations': 1389, 'learning_rate': 0.02866785299107753, 'depth': 4, 'scale_pos_weight': 313.0457769988975, 'l2_leaf_reg': 12.996283974963582, 'border_count': 33, 'random_strength': 0.589058312128901, 'bagging_temperature': 1.2594453292744523}. Best is trial 91 with value: 0.8586225119867786.
# [I 2025-11-30 15:14:37,478] Trial 94 finished with value: 0.8581747805076038 and parameters: {'iterations': 1447, 'learning_rate': 0.028666264722267798, 'depth': 4, 'scale_pos_weight': 301.69587573767274, 'l2_leaf_reg': 13.326583372079503, 'border_count': 37, 'random_strength': 0.7446209705099347, 'bagging_temperature': 1.2918157165908943}. Best is trial 91 with value: 0.8586225119867786.
# [I 2025-11-30 15:15:14,472] Trial 95 finished with value: 0.8564435177497435 and parameters: {'iterations': 1504, 'learning_rate': 0.029988456719589367, 'depth': 4, 'scale_pos_weight': 304.1669664760887, 'l2_leaf_reg': 13.90739665359598, 'border_count': 38, 'random_strength': 0.7798854948821559, 'bagging_temperature': 1.302464487369053}. Best is trial 91 with value: 0.8586225119867786.
# [I 2025-11-30 15:15:56,313] Trial 96 finished with value: 0.8569884455458899 and parameters: {'iterations': 1445, 'learning_rate': 0.028285479119350643, 'depth': 4, 'scale_pos_weight': 295.8608123482457, 'l2_leaf_reg': 13.399604920388684, 'border_count': 36, 'random_strength': 0.9162520358104762, 'bagging_temperature': 1.3337246031186403}. Best is trial 91 with value: 0.8586225119867786.
# [I 2025-11-30 15:16:36,497] Trial 97 finished with value: 0.8573177032738587 and parameters: {'iterations': 1559, 'learning_rate': 0.02693831928121825, 'depth': 4, 'scale_pos_weight': 332.1914954797143, 'l2_leaf_reg': 12.099802567780308, 'border_count': 42, 'random_strength': 0.7333345742678343, 'bagging_temperature': 1.4129552693266156}. Best is trial 91 with value: 0.8586225119867786.
# [I 2025-11-30 15:17:11,288] Trial 98 finished with value: 0.8562801763571839 and parameters: {'iterations': 1327, 'learning_rate': 0.027073426427532563, 'depth': 4, 'scale_pos_weight': 344.46516124098855, 'l2_leaf_reg': 11.919116237652041, 'border_count': 42, 'random_strength': 0.7572587494955885, 'bagging_temperature': 1.418964765032978}. Best is trial 91 with value: 0.8586225119867786.
# [I 2025-11-30 15:17:44,573] Trial 99 finished with value: 0.8558240353829989 and parameters: {'iterations': 1550, 'learning_rate': 0.02729203382596178, 'depth': 4, 'scale_pos_weight': 313.51635190377294, 'l2_leaf_reg': 12.752599716085252, 'border_count': 47, 'random_strength': 0.3276847629384447, 'bagging_temperature': 1.277370559351137}. Best is trial 91 with value: 0.8586225119867786.
# [I 2025-11-30 15:18:12,616] Trial 100 finished with value: 0.8564921863834324 and parameters: {'iterations': 1356, 'learning_rate': 0.02914567842260136, 'depth': 4, 'scale_pos_weight': 328.58177563688116, 'l2_leaf_reg': 12.973310470128178, 'border_count': 40, 'random_strength': 0.7275453572769527, 'bagging_temperature': 0.028087226085790284}. Best is trial 91 with value: 0.8586225119867786.
# [I 2025-11-30 15:18:53,585] Trial 101 finished with value: 0.8571201786678642 and parameters: {'iterations': 1496, 'learning_rate': 0.025177929954360058, 'depth': 4, 'scale_pos_weight': 289.5288208847228, 'l2_leaf_reg': 13.685495498288217, 'border_count': 37, 'random_strength': 0.8334993236254125, 'bagging_temperature': 1.3841790456099181}. Best is trial 91 with value: 0.8586225119867786.
# [I 2025-11-30 15:19:34,452] Trial 102 finished with value: 0.8566376546766122 and parameters: {'iterations': 1571, 'learning_rate': 0.02483249076190464, 'depth': 4, 'scale_pos_weight': 329.5877720467843, 'l2_leaf_reg': 12.273065147612215, 'border_count': 36, 'random_strength': 0.8164959277453113, 'bagging_temperature': 1.3699015254055353}. Best is trial 91 with value: 0.8586225119867786.

# %%
best_params = {'iterations': 1486,
                                               'learning_rate': 0.028711863825961668,
                                               'depth': 3,
                                               'scale_pos_weight': 304.53677886131595,
                                               'l2_leaf_reg': 14.072790632515524,
                                               'border_count': 78,
                                               'random_strength': 0.47114280903385825,
                                               'bagging_temperature': 0.5886678131427623,
                                               "verbose": 250}

best_params = set_to_gpu(best_params)

kf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=42)
score = cv_score_catboost(params=best_params,
                              X=X_train_full,
                              y=y_train_full,
                              cv=kf,
                              metric='balanced_accuracy')
round(score, 3)
# Out:
# np.float64(0.856)

# %%
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = []
for train_idx, val_idx in kf.split(X_train_full, y_train_full):
        X_train, y_train = X_train_full.iloc[train_idx], y_train_full.iloc[train_idx]
        X_val, y_val = X_train_full.iloc[val_idx], y_train_full.iloc[val_idx]

        model = catboost.CatBoostClassifier(**{'iterations': 1486,
                                               'learning_rate': 0.028711863825961668,
                                               'depth': 3,
                                               'scale_pos_weight': 304.53677886131595,
                                               'l2_leaf_reg': 14.072790632515524,
                                               'border_count': 78,
                                               'random_strength': 0.47114280903385825,
                                               'bagging_temperature': 0.5886678131427623,
                                               "task_type": "GPU",
                                               "devices": "0",
                                               "verbose": 250})
        model.fit(X_train, y_train, eval_set=(X_val, y_val),  verbose=250, early_stopping_rounds=100)
        score = balanced_accuracy_score(y_val, model.predict(X_val))
        scores.append(score)

# %%
round(sum(scores) / len(scores), 2)
# Out:
# np.float64(0.86)

# %% [markdown]
# ### XGBoost

# %%
def xgb_has_gpu():
    try:
        import cupy as cp
        if cp.cuda.runtime.getDeviceCount() > 0:
            return True
    except:
        pass
    try:
        import torch
        if torch.cuda.is_available():
            return True
    except:
        pass
    return False

# %%
def xgboost_param_space(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 500, 2000),
        "learning_rate": trial.suggest_float("learning_rate", 0.005, 0.05, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 8),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 20),
        "reg_lambda": trial.suggest_float("reg_lambda", 0.1, 10.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 0.0, 5.0),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "scale_pos_weight": trial.suggest_float("scale_pos_weight", 100, 400),
        "gamma": trial.suggest_float("gamma", 0.0, 5.0),
        "booster": "gbtree",
        "objective": "binary:logistic",
        "eval_metric": "aucpr",
        "tree_method": "hist",
        "early_stopping_rounds": 100
    }

    if xgb_has_gpu():
        params["device"] = "cuda"
    else:
        params["device"] = "cpu"
    return params

# %%
def cv_score_xgboost(params, X, y, cv, metric='average_precision'):
    scores = []

    for train_idx, val_idx in cv.split(X, y):
        X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
        X_val, y_val = X.iloc[val_idx],  y.iloc[val_idx]

        model = xgb.XGBClassifier(**params)
        model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=250)
        if params['device']=='cuda':
          X_val_gpu = cp.asarray(X_val.values, dtype=cp.float32)
          y_val_proba_gpu = model.get_booster().inplace_predict(X_val_gpu)
          y_val_proba = cp.asnumpy(y_val_proba_gpu)

        else:
          y_val_proba = model.predict_proba(X_val)[:, 1]

        if metric == "average_precision":
            score = average_precision_score(y_val, y_val_proba)
        else:
            # more metrics may be addedd
            raise ValueError("Unknown metric")
        scores.append(score)

    return sum(scores) / len(scores)

# %%
def objective_xgboost(trial):
    params = xgboost_param_space(trial)
    params.setdefault("objective", "binary:logistic")
    kf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=42)
    score = cv_score_xgboost(params=params,
                              X=X_train_full,
                              y=y_train_full,
                              cv=kf)
    return score

# %%
import xgboost
print(xgboost.build_info())
# Out:
# {'BUILTIN_PREFETCH_PRESENT': True, 'CUDA_VERSION': [11, 8], 'DEBUG': False, 'GCC_VERSION': [9, 3, 1], 'MM_PREFETCH_PRESENT': True, 'NCCL_VERSION': [2, 19, 3], 'THRUST_VERSION': [1, 15, 1], 'USE_CUDA': True, 'USE_FEDERATED': True, 'USE_NCCL': True, 'USE_OPENMP': True, 'USE_RMM': False, 'libxgboost': '/usr/local/lib/python3.12/dist-packages/xgboost/lib/libxgboost.so'}

# %%
study_xgboost = optuna.create_study(direction='maximize')
study_xgboost.optimize(objective_xgboost, n_trials=25)
# Out:
# [I 2025-11-28 18:52:14,081] A new study created in memory with name: no-name-f8166168-5ca9-4f2a-9ae2-65a526ddd2c1
# [I 2025-11-28 18:54:00,669] Trial 0 finished with value: 0.11638014825474563 and parameters: {'n_estimators': 1111, 'learning_rate': 0.009759662593418681, 'max_depth': 4, 'min_child_weight': 17, 'reg_lambda': 8.434210735453131, 'reg_alpha': 4.492623525870921, 'subsample': 0.8138915355803797, 'colsample_bytree': 0.7349483535005608, 'scale_pos_weight': 138.4419244707434, 'gamma': 1.7832831888534466}. Best is trial 0 with value: 0.11638014825474563.
# [I 2025-11-28 18:55:38,092] Trial 1 finished with value: 0.10819672029262477 and parameters: {'n_estimators': 1162, 'learning_rate': 0.009345078062783441, 'max_depth': 6, 'min_child_weight': 9, 'reg_lambda': 4.545975656991758, 'reg_alpha': 3.0029545973367338, 'subsample': 0.763327577511148, 'colsample_bytree': 0.6529604598948822, 'scale_pos_weight': 190.66907720633054, 'gamma': 0.7529880808267803}. Best is trial 0 with value: 0.11638014825474563.
# [I 2025-11-28 18:57:08,174] Trial 2 finished with value: 0.11305129426635452 and parameters: {'n_estimators': 750, 'learning_rate': 0.023431574597771346, 'max_depth': 3, 'min_child_weight': 18, 'reg_lambda': 1.2408554454882945, 'reg_alpha': 2.265992845359027, 'subsample': 0.9156214577543372, 'colsample_bytree': 0.7353034616287963, 'scale_pos_weight': 160.2881026084087, 'gamma': 4.515076599976292}. Best is trial 0 with value: 0.11638014825474563.
# [I 2025-11-28 18:58:34,372] Trial 3 finished with value: 0.110059445333753 and parameters: {'n_estimators': 943, 'learning_rate': 0.027939213656123264, 'max_depth': 7, 'min_child_weight': 10, 'reg_lambda': 7.8235276978911505, 'reg_alpha': 1.6147181184195247, 'subsample': 0.7024275680235904, 'colsample_bytree': 0.7657017305613433, 'scale_pos_weight': 269.8853265147777, 'gamma': 4.544150076836887}. Best is trial 0 with value: 0.11638014825474563.
# [I 2025-11-28 19:00:04,821] Trial 4 finished with value: 0.11516436714115093 and parameters: {'n_estimators': 1444, 'learning_rate': 0.013887224611420336, 'max_depth': 4, 'min_child_weight': 3, 'reg_lambda': 4.094209544115331, 'reg_alpha': 4.727143850770455, 'subsample': 0.6794931045703426, 'colsample_bytree': 0.6379944620072479, 'scale_pos_weight': 234.99520239508104, 'gamma': 2.6872120188422803}. Best is trial 0 with value: 0.11638014825474563.
# [I 2025-11-28 19:01:20,269] Trial 5 finished with value: 0.10807435460743671 and parameters: {'n_estimators': 864, 'learning_rate': 0.04019510001434941, 'max_depth': 7, 'min_child_weight': 1, 'reg_lambda': 6.375991880680738, 'reg_alpha': 2.2166377256747745, 'subsample': 0.7332546969176321, 'colsample_bytree': 0.8234002218094627, 'scale_pos_weight': 316.9712913659783, 'gamma': 3.1954097627300078}. Best is trial 0 with value: 0.11638014825474563.
# [I 2025-11-28 19:02:48,340] Trial 6 finished with value: 0.11127800013092791 and parameters: {'n_estimators': 809, 'learning_rate': 0.011253458569926844, 'max_depth': 5, 'min_child_weight': 7, 'reg_lambda': 1.674128593247731, 'reg_alpha': 4.556214073672037, 'subsample': 0.8625240205114859, 'colsample_bytree': 0.9649239781624573, 'scale_pos_weight': 358.39436411561735, 'gamma': 4.9535587992261885}. Best is trial 0 with value: 0.11638014825474563.
# [I 2025-11-28 19:04:26,170] Trial 7 finished with value: 0.11338571793682999 and parameters: {'n_estimators': 811, 'learning_rate': 0.011538143444003104, 'max_depth': 4, 'min_child_weight': 7, 'reg_lambda': 4.938460952481231, 'reg_alpha': 3.621624551726405, 'subsample': 0.8508368484701967, 'colsample_bytree': 0.7836730861083135, 'scale_pos_weight': 313.91504827598203, 'gamma': 4.088890957917887}. Best is trial 0 with value: 0.11638014825474563.
# [I 2025-11-28 19:06:06,456] Trial 8 finished with value: 0.11333042261066262 and parameters: {'n_estimators': 1336, 'learning_rate': 0.01044153747773502, 'max_depth': 5, 'min_child_weight': 5, 'reg_lambda': 3.613577951868473, 'reg_alpha': 4.635360880923141, 'subsample': 0.8548328365212067, 'colsample_bytree': 0.9323160534801029, 'scale_pos_weight': 331.23129219837006, 'gamma': 3.861420280073605}. Best is trial 0 with value: 0.11638014825474563.

# %% [markdown]
# ##### [I 2025-11-28 18:54:00,669] Trial 0 finished with value: 0.11638014825474563 and parameters: {'n_estimators': 1111, 'learning_rate': 0.009759662593418681, 'max_depth': 4, 'min_child_weight': 17, 'reg_lambda': 8.434210735453131, 'reg_alpha': 4.492623525870921, 'subsample': 0.8138915355803797, 'colsample_bytree': 0.7349483535005608, 'scale_pos_weight': 138.4419244707434, 'gamma': 1.7832831888534466}.

# %%
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = []
for train_idx, val_idx in kf.split(X_train_full, y_train_full):
        X_train, y_train = X_train_full.iloc[train_idx], y_train_full.iloc[train_idx]
        X_val, y_val = X_train_full.iloc[val_idx], y_train_full.iloc[val_idx]

        model = xgb.XGBClassifier(**{'n_estimators': 1111,
                                     'learning_rate': 0.009759662593418681,
                                     'max_depth': 4, 'min_child_weight': 17,
                                     'reg_lambda': 8.434210735453131,
                                     'reg_alpha': 4.492623525870921,
                                     'subsample': 0.8138915355803797,
                                     'colsample_bytree': 0.7349483535005608,
                                     'scale_pos_weight': 138.4419244707434,
                                     'gamma': 1.7832831888534466,
                                     "eval_metric": "aucpr",
                                     "tree_method": "hist",
                                     "device": "cuda",
                                     "early_stopping_rounds": 100})

        model.fit(X_train, y_train, eval_set=[(X_val, y_val)],  verbose=250)

        score = balanced_accuracy_score(y_val, model.predict(X_val))
        scores.append(score)
print(sum(scores) / len(scores))
# Out:
# [0]	validation_0-aucpr:0.05653
# [250]	validation_0-aucpr:0.13084
# [462]	validation_0-aucpr:0.13199
# /usr/local/lib/python3.12/dist-packages/xgboost/core.py:160: UserWarning: [19:50:58] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# [0]	validation_0-aucpr:0.05036
# [250]	validation_0-aucpr:0.09919
# [500]	validation_0-aucpr:0.10252
# [750]	validation_0-aucpr:0.10605
# [1000]	validation_0-aucpr:0.10819
# [1110]	validation_0-aucpr:0.10833
# [0]	validation_0-aucpr:0.05425
# [250]	validation_0-aucpr:0.12159
# [500]	validation_0-aucpr:0.13521
# [719]	validation_0-aucpr:0.13800
# [0]	validation_0-aucpr:0.04961
# [250]	validation_0-aucpr:0.10062
# [500]	validation_0-aucpr:0.10714
# [750]	validation_0-aucpr:0.10979
# [811]	validation_0-aucpr:0.10999
# [0]	validation_0-aucpr:0.04230
# [250]	validation_0-aucpr:0.09153
# [500]	validation_0-aucpr:0.09764
# [750]	validation_0-aucpr:0.09953
# [1000]	validation_0-aucpr:0.10057
# [1110]	validation_0-aucpr:0.10075
# 0.8433335340381181

# %% [markdown]
# # Summary

# %% [markdown]
# ### Catboost showed the best results
